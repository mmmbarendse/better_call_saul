# %%
from grid_search import GridSearch
from crime_model_02 import CrimeModel

# %%
# running simulation
parameters = {"N": [100], 
             "deterrence": [0.001, 0.01, 0.1, 0.2, 0.5, 0.75, 1], 
             "gamma_alpha": [2], 
             "gamma_beta": [2], 
             "steps": [100], 
             "distribution": ["gamma"],
             "fraction_stolen": [(0.4, 0.1)]
              }
    
gs = GridSearch(CrimeModel, parameters)
gs.run_search()
# Out:
# Combination 1/7
# Parameters: {'N': 100, 'deterrence': 0.001, 'gamma_alpha': 2, 'gamma_beta': 2, 'steps': 100, 'distribution': 'gamma', 'fraction_stolen': (0.4, 0.1)}
# C:\Users\Nutzer\Desktop\Studium CSS\05 Kurse\02 SS24\Computational Modeling of Social Systems\CMS_Project\better_call_saul\crime_model_02.py:8: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# C:\Users\Nutzer\Desktop\Studium CSS\05 Kurse\02 SS24\Computational Modeling of Social Systems\CMS_Project\better_call_saul\crime_model_02.py:8: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)
# Combination 2/7
# ...

# %%
gs.view_results()
# Out:
#      N  deterrence  gamma_alpha  gamma_beta  steps distribution  \
# 0  100       0.001            2           2    100        gamma
# 1  100       0.010            2           2    100        gamma
# 2  100       0.100            2           2    100        gamma
# 3  100       0.200            2           2    100        gamma
# 4  100       0.500            2           2    100        gamma
# 5  100       0.750            2           2    100        gamma
# 6  100       1.000            2           2    100        gamma
#
#   fraction_stolen  gini_start  gini_end  crime_rate  \
# 0      (0.4, 0.1)    0.393176  0.292742        1.00
# 1      (0.4, 0.1)    0.381631  0.328244        1.00
# 2      (0.4, 0.1)    0.365353  0.284735        1.00
# 3      (0.4, 0.1)    0.386135  0.299005        0.99
# 4      (0.4, 0.1)    0.383723  0.279058        1.00
# 5      (0.4, 0.1)    0.359163  0.274579        1.00
# 6      (0.4, 0.1)    0.361597  0.239008        0.99
#
# ...

# %%
gs.model_plots([3])

# %%
gs.create_boxplot()
