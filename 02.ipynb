# %%
from distribution import gamma, gini
from grid_search import GridSearch
from crime_model_02 import CrimeModel

# %%
# running simulation
parameters = {"N": [100], 
             "deterrence": [0.5], 
             "gamma_alpha": [2], 
             "gamma_beta": [2], 
             "steps": [100], 
             "distribution": ["gamma"], 
             "fraction_stolen": [(0.1, 0.3)]}
    
gs = GridSearch(CrimeModel, parameters)
gs.run_search()
# Out:
# Combination 1/1
# Parameters: {'N': 100, 'deterrence': 0.5, 'gamma_alpha': 2, 'gamma_beta': 2, 'steps': 100, 'distribution': 'gamma', 'fraction_stolen': (0.1, 0.3)}
# C:\Users\Nutzer\Desktop\Studium CSS\05 Kurse\02 SS24\Computational Modeling of Social Systems\CMS_Project\better_call_saul\crime_model.py:7: FutureWarning: The Mesa Model class was not initialized. In the future, you need to explicitly initialize the Model by calling super().__init__() on initialization.
#   super().__init__(unique_id, model)

# %%
gs.view_results()
# Out:
#      N  deterrence  gamma_alpha  gamma_beta  steps distribution  \
# 0  100         0.5            2           2    100        gamma
#
#   fraction_stolen  gini_start  gini_end  crime_rate  \
# 0      (0.1, 0.3)    0.402983  0.402983        0.78
#
#                                     wealth_arr_start  \
# 0  [5.620776664230561, 1.6865350342277565, 1.1311...
#
#                                       wealth_arr_end  \
# 0  [5.620776664230561, 1.6865350342277565, 1.1311...
#
#                                       gini_over_time  \
# 0  [0.4029833483880505, 0.4029833483880505, 0.402...
#
#                                 crime_rate_over_time
# 0  [0.0, 0.31, 0.41, 0.51, 0.57, 0.62, 0.68, 0.69...

# %%
gs.model_plots([0])

# %%
gs.create_boxplot()
